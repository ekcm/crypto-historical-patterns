# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->kagglehub) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->kagglehub) (2024.8.30)
# Downloading kagglehub-0.3.6-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.6

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mczielinski/bitcoin-historical-data")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mczielinski/bitcoin-historical-data?dataset_version_number=143...
# 100%|██████████████████████████████████████| 89.8M/89.8M [00:03<00:00, 28.5MB/s]
# Extracting files...
# Path to dataset files: /Users/elijahkhor/.cache/kagglehub/datasets/mczielinski/bitcoin-historical-data/versions/143

# %%
import pandas as pd

file_path = "./data/btcusd_1-min_data.csv"

df = pd.read_csv(file_path)

# %%
df
# Out:
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 6749276  1.737763e+09  104853.00  104865.00  104833.00  104857.00  0.684220
# 6749277  1.737763e+09  104850.00  104850.00  104817.00  104831.00  0.305882
# 6749278  1.737763e+09  104855.00  104855.00  104848.00  104855.00  0.002753
# 6749279  1.737763e+09  104855.00  104855.00  104711.00  104711.00  0.603881
# 6749280           NaN   57854.00   57864.00   57835.00   57835.00  1.353466
#
# [6749281 rows x 6 columns]

# %%
df.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  6.749280e+06  6.749281e+06  6.749281e+06  6.749281e+06  6.749281e+06
# mean   1.527949e+09  1.471059e+04  1.471691e+04  1.470408e+04  1.471061e+04
# std    1.169780e+08  2.000668e+04  2.001431e+04  1.999892e+04  2.000676e+04
# min    1.325412e+09  3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00
# 25%    1.426662e+09  4.138400e+02  4.139800e+02  4.136500e+02  4.138300e+02
# 50%    1.527912e+09  6.273630e+03  6.276290e+03  6.270690e+03  6.273630e+03
# 75%    1.629162e+09  2.325958e+04  2.326800e+04  2.325084e+04  2.326000e+04
# max    1.737763e+09  1.089460e+05  1.090300e+05  1.087760e+05  1.089600e+05
#
#              Volume
# count  6.749281e+06
# mean   5.457175e+00
# std    2.292165e+01
# min    0.000000e+00
# 25%    1.832143e-02
# 50%    5.000000e-01
# 75%    3.173861e+00
# max    5.853852e+03

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
df
# Out:
#                   Timestamp       Open       High        Low      Close  \
# 0       2012-01-01 10:01:00       4.58       4.58       4.58       4.58
# 1       2012-01-01 10:02:00       4.58       4.58       4.58       4.58
# 2       2012-01-01 10:03:00       4.58       4.58       4.58       4.58
# 3       2012-01-01 10:04:00       4.58       4.58       4.58       4.58
# 4       2012-01-01 10:05:00       4.58       4.58       4.58       4.58
# ...                     ...        ...        ...        ...        ...
# 6749276 2025-01-24 23:57:00  104853.00  104865.00  104833.00  104857.00
# 6749277 2025-01-24 23:58:00  104850.00  104850.00  104817.00  104831.00
# 6749278 2025-01-24 23:59:00  104855.00  104855.00  104848.00  104855.00
# 6749279 2025-01-25 00:00:00  104855.00  104855.00  104711.00  104711.00
# 6749280                 NaT   57854.00   57864.00   57835.00   57835.00
#
#            Volume
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 6749276  0.684220
# 6749277  0.305882
# 6749278  0.002753
# 6749279  0.603881
# 6749280  1.353466
#
# [6749281 rows x 6 columns]

# %%
# Using matplotlib and seaborn for better styling
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# Create a figure with larger size
plt.figure(figsize=(15, 8))

# Plot closing price over time
plt.plot(df['Timestamp'], df['Close'])
plt.title('Bitcoin Price History')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create a volume plot
plt.figure(figsize=(15, 4))
plt.bar(df['Timestamp'], df['Volume'], alpha=0.7)
plt.title('Bitcoin Trading Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 20
#      18 # Create a volume plot
#      19 plt.figure(figsize=(15, 4))
# ---> 20 plt.bar(df['Timestamp'], df['Volume'], alpha=0.7)
#      21 plt.title('Bitcoin Trading Volume')
#      22 plt.xlabel('Date')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:2538, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2536     else:  # horizontal
#    2537         r.sticky_edges.x.append(l)
# -> 2538     self.add_patch(r)
#    2539     patches.append(r)
#    2541 if xerr is not None or yerr is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:2384, in _AxesBase.add_patch(self, p)
#    2382 if p.get_clip_path() is None:
#    2383     p.set_clip_path(self.patch)
# -> 2384 self._update_patch_limits(p)
#    2385 self._children.append(p)
#    2386 p._remove_method = self._children.remove
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:2416, in _AxesBase._update_patch_limits(self, patch)
#    2413     vertices = np.vstack(vertices)
#    2415 patch_trf = patch.get_transform()
# -> 2416 updatex, updatey = patch_trf.contains_branch_seperately(self.transData)
#    2417 if not (updatex or updatey):
#    2418     return
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:1416, in Transform.contains_branch_seperately(self, other_transform)
#    1412     raise ValueError('contains_branch_seperately only supports '
#    1413                      'transforms with 2 output dimensions')
#    1414 # for a non-blended transform each separate dimension is the same, so
#    1415 # just return the appropriate shape.
# -> 1416 return [self.contains_branch(other_transform)] * 2
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:1395, in Transform.contains_branch(self, other)
#    1392     return False
#    1394 # check that a subtree is equal to other (starting from self)
# -> 1395 for _, sub_tree in self._iter_break_from_left_to_right():
#    1396     if sub_tree == other:
#    1397         return True
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2392, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2391 def _iter_break_from_left_to_right(self):
# -> 2392     for left, right in self._a._iter_break_from_left_to_right():
#    2393         yield left, right + self._b
#    2394     for left, right in self._b._iter_break_from_left_to_right():
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2393, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2391 def _iter_break_from_left_to_right(self):
#    2392     for left, right in self._a._iter_break_from_left_to_right():
# -> 2393         yield left, right + self._b
#    2394     for left, right in self._b._iter_break_from_left_to_right():
#    2395         yield self._a + left, right
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:1347, in Transform.__add__(self, other)
#    1340 def __add__(self, other):
#    1341     """
#    1342     Compose two transforms together so that *self* is followed by *other*.
#    1343
#    1344     ``A + B`` returns a transform ``C`` so that
#    1345     ``C.transform(x) == B.transform(A.transform(x))``.
#    1346     """
# -> 1347     return (composite_transform_factory(self, other)
#    1348             if isinstance(other, Transform) else
#    1349             NotImplemented)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2522, in composite_transform_factory(a, b)
#    2520 elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2521     return CompositeAffine2D(a, b)
# -> 2522 return CompositeGenericTransform(a, b)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2363, in CompositeGenericTransform.__init__(self, a, b, **kwargs)
#    2360 self.input_dims = a.input_dims
#    2361 self.output_dims = b.output_dims
# -> 2363 super().__init__(**kwargs)
#    2364 self._a = a
#    2365 self._b = b
#
# KeyboardInterrupt:

# %%
df
# Out:
#                   Timestamp       Open       High        Low      Close  \
# 0       2012-01-01 10:01:00       4.58       4.58       4.58       4.58
# 1       2012-01-01 10:02:00       4.58       4.58       4.58       4.58
# 2       2012-01-01 10:03:00       4.58       4.58       4.58       4.58
# 3       2012-01-01 10:04:00       4.58       4.58       4.58       4.58
# 4       2012-01-01 10:05:00       4.58       4.58       4.58       4.58
# ...                     ...        ...        ...        ...        ...
# 6749276 2025-01-24 23:57:00  104853.00  104865.00  104833.00  104857.00
# 6749277 2025-01-24 23:58:00  104850.00  104850.00  104817.00  104831.00
# 6749278 2025-01-24 23:59:00  104855.00  104855.00  104848.00  104855.00
# 6749279 2025-01-25 00:00:00  104855.00  104855.00  104711.00  104711.00
# 6749280                 NaT   57854.00   57864.00   57835.00   57835.00
#
#            Volume
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 6749276  0.684220
# 6749277  0.305882
# 6749278  0.002753
# 6749279  0.603881
# 6749280  1.353466
#
# [6749281 rows x 6 columns]

# %%
# Convert the target dates to pandas datetime
start_date = pd.to_datetime('2012-11-28 15:24:37')
end_date = pd.to_datetime('2016-07-09 16:46:13')

# Filter the dataframe - corrected syntax
block_period = df[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date)]
block_period['Halving'] = 1

# Optional: Verify the new column
print(block_period[['Timestamp', 'Close', 'Halving']].head())

df['Halving'] = 0

df.loc[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date), 'Halving'] = 1

print(df[['Timestamp', 'Close', 'Halving']].head())
print("\nRows around the start date:")
print(df[df['Timestamp'].dt.date == start_date.date()][['Timestamp', 'Close', 'Halving']].head())
# Out:
# /var/folders/8v/897mbqq15hqg4wyxnrxm9f_m0000gn/T/ipykernel_3704/2259664191.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_period['Halving'] = 1
#                  Timestamp  Close  Halving
# 478344 2012-11-28 15:25:00   12.1        1
# 478345 2012-11-28 15:26:00   12.1        1
# 478346 2012-11-28 15:27:00   12.1        1
# 478347 2012-11-28 15:28:00   12.1        1
# 478348 2012-11-28 15:29:00   12.1        1
#             Timestamp  Close  Halving
# 0 2012-01-01 10:01:00   4.58        0
# 1 2012-01-01 10:02:00   4.58        0
# 2 2012-01-01 10:03:00   4.58        0
# 3 2012-01-01 10:04:00   4.58        0
# 4 2012-01-01 10:05:00   4.58        0
#
# Rows around the start date:
#                  Timestamp  Close  Halving
# 477419 2012-11-28 00:00:00  11.95        0
# 477420 2012-11-28 00:01:00  11.95        0
# 477421 2012-11-28 00:02:00  11.95        0
# 477422 2012-11-28 00:03:00  11.95        0
# 477423 2012-11-28 00:04:00  11.95        0

# %%
# second halving

start_date = pd.to_datetime('2016-07-09 16:46:13')
end_date = pd.to_datetime('2020-05-11 19:23:43')

# Filter the dataframe - corrected syntax
block_period = df[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date)]
block_period['Halving'] = 2

# Optional: Verify the new column
print(block_period[['Timestamp', 'Close', 'Halving']].head())

df.loc[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date), 'Halving'] = 2

print(df[['Timestamp', 'Close', 'Halving']].head())
print("\nRows around the start date:")
print(df[df['Timestamp'].dt.date == start_date.date()][['Timestamp', 'Close', 'Halving']].head())
# Out:
# /var/folders/8v/897mbqq15hqg4wyxnrxm9f_m0000gn/T/ipykernel_3704/3270033674.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_period['Halving'] = 2
#                   Timestamp   Close  Halving
# 2377606 2016-07-09 16:47:00  646.34        2
# 2377607 2016-07-09 16:48:00  646.34        2
# 2377608 2016-07-09 16:49:00  644.69        2
# 2377609 2016-07-09 16:50:00  646.94        2
# 2377610 2016-07-09 16:51:00  646.79        2
#             Timestamp  Close  Halving
# 0 2012-01-01 10:01:00   4.58        0
# 1 2012-01-01 10:02:00   4.58        0
# 2 2012-01-01 10:03:00   4.58        0
# 3 2012-01-01 10:04:00   4.58        0
# 4 2012-01-01 10:05:00   4.58        0
#
# Rows around the start date:
#                   Timestamp   Close  Halving
# 2376599 2016-07-09 00:00:00  654.00        1
# 2376600 2016-07-09 00:01:00  654.00        1
# 2376601 2016-07-09 00:02:00  653.87        1
# 2376602 2016-07-09 00:03:00  653.87        1
# 2376603 2016-07-09 00:04:00  653.98        1

# %%
start_date = pd.to_datetime('2020-05-11 19:23:43')
end_date = pd.to_datetime('2024-04-20 12:09:27')

# Filter the dataframe - corrected syntax
block_period = df[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date)]
block_period['Halving'] = 3

# Optional: Verify the new column
print(block_period[['Timestamp', 'Close', 'Halving']].head())

df.loc[(df['Timestamp'] >= start_date) & (df['Timestamp'] <= end_date), 'Halving'] = 3

print(df[['Timestamp', 'Close', 'Halving']].head())
print("\nRows around the start date:")
print(df[df['Timestamp'].dt.date == start_date.date()][['Timestamp', 'Close', 'Halving']].head())
# Out:
# /var/folders/8v/897mbqq15hqg4wyxnrxm9f_m0000gn/T/ipykernel_3704/434634872.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_period['Halving'] = 3
#                   Timestamp    Close  Halving
# 4396403 2020-05-11 19:24:00  8917.00        3
# 4396404 2020-05-11 19:25:00  8928.23        3
# 4396405 2020-05-11 19:26:00  8931.80        3
# 4396406 2020-05-11 19:27:00  8927.67        3
# 4396407 2020-05-11 19:28:00  8926.58        3
#             Timestamp  Close  Halving
# 0 2012-01-01 10:01:00   4.58        0
# 1 2012-01-01 10:02:00   4.58        0
# 2 2012-01-01 10:03:00   4.58        0
# 3 2012-01-01 10:04:00   4.58        0
# 4 2012-01-01 10:05:00   4.58        0
#
# Rows around the start date:
#                   Timestamp    Close  Halving
# 4395239 2020-05-11 00:00:00  8552.87        2
# 4395240 2020-05-11 00:01:00  8649.21        2
# 4395241 2020-05-11 00:02:00  8714.96        2
# 4395242 2020-05-11 00:03:00  8768.24        2
# 4395243 2020-05-11 00:04:00  8745.70        2

# %%
start_date = pd.to_datetime('2012-11-28 15:24:37')

# Count rows before start_date
count = len(df[df['Timestamp'] < start_date])
print(f"Number of rows before {start_date}: {count}")
# Out:
# Number of rows before 2012-11-28 15:24:37: 478344

# %%
end_date = pd.to_datetime('2024-04-20 12:09:27')

# Count rows before start_date
count = len(df[df['Timestamp'] > end_date])
print(f"Number of rows before {end_date}: {count}")
# Out:
# Number of rows before 2024-04-20 12:09:27: 279951

# %%
start_date = pd.to_datetime('2012-11-28 15:24:37')

# Delete rows before start_date using boolean indexing
df = df[df['Timestamp'] >= start_date].copy()

# Verify the new size
print(f"Number of rows in dataframe after deletion: {len(df)}")
# Out:
# Number of rows in dataframe after deletion: 6270936

# %%
end_date = pd.to_datetime('2024-04-20 12:09:27')

# Assign Halving = 4 to rows after end_date
df.loc[df['Timestamp'] > end_date, 'Halving'] = 4

# Verify the changes
print("Value counts in Halving column:")
print(df['Halving'].value_counts())
# Out:
# Value counts in Halving column:
# Halving
# 3    2072926
# 2    2018797
# 1    1899262
# 0     478345
# 4     279951
# Name: count, dtype: int64

# %%
df
# Out:
#                   Timestamp       Open       High        Low      Close  \
# 0       2012-01-01 10:01:00       4.58       4.58       4.58       4.58
# 1       2012-01-01 10:02:00       4.58       4.58       4.58       4.58
# 2       2012-01-01 10:03:00       4.58       4.58       4.58       4.58
# 3       2012-01-01 10:04:00       4.58       4.58       4.58       4.58
# 4       2012-01-01 10:05:00       4.58       4.58       4.58       4.58
# ...                     ...        ...        ...        ...        ...
# 6749276 2025-01-24 23:57:00  104853.00  104865.00  104833.00  104857.00
# 6749277 2025-01-24 23:58:00  104850.00  104850.00  104817.00  104831.00
# 6749278 2025-01-24 23:59:00  104855.00  104855.00  104848.00  104855.00
# 6749279 2025-01-25 00:00:00  104855.00  104855.00  104711.00  104711.00
# 6749280                 NaT   57854.00   57864.00   57835.00   57835.00
#
#            Volume  Halving
# 0        0.000000        0
# 1        0.000000        0
# 2        0.000000        0
# 3        0.000000        0
# 4        0.000000        0
# ...           ...      ...
# 6749276  0.684220        4
# 6749277  0.305882        4
# 6749278  0.002753        4
# 6749279  0.603881        4
# 6749280  1.353466        0
#
# [6749281 rows x 7 columns]

# %%
# Export the DataFrame with halving cycles labeled
output_path = './data/bitcoin_price_with_halving_cycles.csv'
df.to_csv(output_path, index=False)
print(f"DataFrame exported to: {output_path}")
# Out:
# DataFrame exported to: ./data/bitcoin_price_with_halving_cycles.csv

# %% [markdown]
# you can now import the updated dataset with halving cycles here

# %%
import pandas as pd

# Define the path to the CSV file
output_path = './data/bitcoin_price_with_halving_cycles.csv'

# Load the DataFrame from the CSV file
df = pd.read_csv(output_path)

# Display the first few rows of the DataFrame to verify
print(df.head())
# Out:
#              Timestamp  Open  High   Low  Close  Volume  Halving
# 0  2012-11-28 15:25:00  12.1  12.1  12.1   12.1     0.0        1
# 1  2012-11-28 15:26:00  12.1  12.1  12.1   12.1     0.0        1
# 2  2012-11-28 15:27:00  12.1  12.1  12.1   12.1     0.0        1
# 3  2012-11-28 15:28:00  12.1  12.1  12.1   12.1     0.0        1
# 4  2012-11-28 15:29:00  12.1  12.1  12.1   12.1     0.0        1

# %%
df
# Out:
#                          Open      High       Low     Close    Volume  Halving
# Timestamp
# 2012-11-28 15:25:00      12.1      12.1      12.1      12.1  0.000000        1
# 2012-11-28 15:26:00      12.1      12.1      12.1      12.1  0.000000        1
# 2012-11-28 15:27:00      12.1      12.1      12.1      12.1  0.000000        1
# 2012-11-28 15:28:00      12.1      12.1      12.1      12.1  0.000000        1
# 2012-11-28 15:29:00      12.1      12.1      12.1      12.1  0.000000        1
# ...                       ...       ...       ...       ...       ...      ...
# 2025-01-24 23:56:00  104817.0  104859.0  104817.0  104857.0  0.849548        4
# 2025-01-24 23:57:00  104853.0  104865.0  104833.0  104857.0  0.684220        4
# 2025-01-24 23:58:00  104850.0  104850.0  104817.0  104831.0  0.305882        4
# 2025-01-24 23:59:00  104855.0  104855.0  104848.0  104855.0  0.002753        4
# 2025-01-25 00:00:00  104855.0  104855.0  104711.0  104711.0  0.603881        4
#
# [6270936 rows x 6 columns]

# %%
print(len(daily_df))

print(len(df))
# Out:
# 4442
# 6270936

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create single plot
fig, ax1 = plt.subplots(figsize=(15, 8))

# Plot price trends by halving cycle
for cycle in sorted(df['Halving'].unique()):
    cycle_data = df[df['Halving'] == cycle]
    ax1.plot(cycle_data['Timestamp'], cycle_data['Close'], 
             label=f'Halving {cycle}', alpha=0.8)

ax1.set_title('Bitcoin Price During Different Halving Cycles')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price (USD)')
ax1.legend()
# ax1.set_yscale('log')  # Using log scale since price changes are exponential
ax1.grid(True)

plt.tight_layout()
plt.show()

# Alternative visualization: Normalized price changes
plt.figure(figsize=(15, 8))

for cycle in sorted(df['Halving'].unique()):
    cycle_data = df[df['Halving'] == cycle]
    # Normalize prices to start at 100 for each cycle
    normalized_prices = cycle_data['Close'] / cycle_data['Close'].iloc[0] * 100
    # Create relative timeindex (days from start of cycle)
    days_from_start = (cycle_data['Timestamp'] - cycle_data['Timestamp'].iloc[0]).dt.total_seconds() / (24*60*60)
    
    plt.plot(days_from_start, normalized_prices, label=f'Halving {cycle}', alpha=0.8)

plt.title('Normalized Bitcoin Price Changes by Halving Cycle')
plt.xlabel('Days from Start of Cycle')
plt.ylabel('Price (Normalized to 100)')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Alternative visualization: Normalized price changes
plt.figure(figsize=(15, 8))

for cycle in sorted(df['Halving'].unique()):
    cycle_data = df[df['Halving'] == cycle]
    # Normalize prices to start at 100 for each cycle
    normalized_prices = cycle_data['Close'] / cycle_data['Close'].iloc[0] * 100
    # Create relative timeindex (days from start of cycle)
    days_from_start = (cycle_data['Timestamp'] - cycle_data['Timestamp'].iloc[0]).dt.total_seconds() / (24*60*60)
    
    plt.plot(days_from_start, normalized_prices, label=f'Halving {cycle}', alpha=0.8)

plt.title('Normalized Bitcoin Price Changes by Halving Cycle')
plt.xlabel('Days from Start of Cycle')
plt.ylabel('Price (Normalized to 100)')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
# Get the start date of the first halving cycle
first_halving_start = pd.to_datetime('2012-11-28 15:24:37')

# Calculate start date (day 200) and end date (day 400)
day_200_date = first_halving_start + pd.Timedelta(days=200)
day_400_date = first_halving_start + pd.Timedelta(days=400)

print(f"Day 200: {day_200_date.strftime('%Y-%m-%d')}")
print(f"Day 400: {day_400_date.strftime('%Y-%m-%d')}")
# Out:
# Day 200: 2013-06-16
# Day 400: 2014-01-02

# %%
# Alternative visualization: Normalized price changes
plt.figure(figsize=(15, 8))

for cycle in sorted(df['Halving'].unique()):
    cycle_data = df[df['Halving'] == cycle]
    # Create relative timeindex (days from start of cycle)
    days_from_start = (cycle_data['Timestamp'] - cycle_data['Timestamp'].iloc[0]).dt.total_seconds() / (24*60*60)
    
    # Filter for days between 200 and 400
    mask = (days_from_start >= 200) & (days_from_start <= 400)
    filtered_days = days_from_start[mask]
    
    # Normalize prices to start at 100 for each cycle
    normalized_prices = cycle_data['Close'] / cycle_data['Close'].iloc[0] * 100
    filtered_prices = normalized_prices[mask]
    
    plt.plot(filtered_days, filtered_prices, label=f'Halving {cycle}', alpha=0.8)

plt.title('Normalized Bitcoin Price Changes by Halving Cycle (Days 200-400)')
plt.xlabel('Days from Start of Cycle')
plt.ylabel('Price (Normalized to 100)')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %% [markdown]
# first halving key events to plot:
# bad news
# - December 5, 2013 - People's bank of China prohibited banks from processing Bitcoin transactions -> triggered 28% price drop
# - October 2013 - FBI shut down Silk Road
# - Mt. Gox - largest bitcoin exchange began experiencing transaction malleability issues
#
# good news
# - December 11, 2013 - Microsoft ccept Bitcoin for Xbox games, and mobile content
# - October 2013, world's first bitcoin atm was installed
# - Rise of cryptocurrency exchanges
# - increased media exposure

# %%
import pandas as pd

# Define start dates for each halving cycle
halving_start_dates = {
    1: pd.to_datetime('2012-11-28 15:24:37'),
    2: pd.to_datetime('2016-07-09 16:46:13'),
    3: pd.to_datetime('2020-05-11 19:23:43'),
    4: pd.to_datetime('2024-04-20 12:09:27')  # Example date for the fourth cycle
}

# Calculate the 200th and 400th day for each cycle
halving_date_ranges = {}
for cycle, start_date in halving_start_dates.items():
    day_200 = start_date + pd.Timedelta(days=200)
    day_400 = start_date + pd.Timedelta(days=400)
    halving_date_ranges[cycle] = (day_200, day_400)

# Print the first and last date of the date range for each halving cycle
for cycle, (day_200, day_400) in halving_date_ranges.items():
    print(f"Cycle {cycle}:")
    print(f"  Start of 200-day range: {day_200.strftime('%Y-%m-%d')}")
    print(f"  End of 400-day range: {day_400.strftime('%Y-%m-%d')}\n")
# Out:
# Cycle 1:
#   Start of 200-day range: 2013-06-16
#   End of 400-day range: 2014-01-02
#
# Cycle 2:
#   Start of 200-day range: 2017-01-25
#   End of 400-day range: 2017-08-13
#
# Cycle 3:
#   Start of 200-day range: 2020-11-27
#   End of 400-day range: 2021-06-15
#
# Cycle 4:
#   Start of 200-day range: 2024-11-06
#   End of 400-day range: 2025-05-25

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the 'Timestamp' and 'Halving' columns

# Define target dates
negative_events = [
    pd.to_datetime('2013-12-05'),  # China ban
    pd.to_datetime('2013-10-02'),  # Silk Road shutdown
    pd.to_datetime('2013-06-16'),  # Mt. Gox halted USD withdrawals
    pd.to_datetime('2013-08-05'),  # Mt. Gox announced losses
    pd.to_datetime('2017-08-01'),  # bitcoin hard fork
    pd.to_datetime('2017-03-10'),  # SEC rejects the winklevoss bitcoin etf
    pd.to_datetime('2017-05-12'),  # wannacry ransomwhere attack
    pd.to_datetime('2021-05-12'),  # Elon Musk u-turn on bitcoin
    pd.to_datetime('2021-05-19'),  # Market crash?
]

positive_events = [
    pd.to_datetime('2013-12-11'),  # Microsoft accepts bitcoin
    pd.to_datetime('2013-10-29'),   # First bitcoin ATM installed
    pd.to_datetime('2013-07-03'),   # EOS and Tezos launches
    pd.to_datetime('2017-07-21'),   #BIP-91 acitivated
    pd.to_datetime('2021-02-08'),  # Tesla buys bitcoin
    pd.to_datetime('2021-04-14'),  # Coinbase IPO
    pd.to_datetime('2021-06-09'),  # el salvador adopts bitcoin
]

plt.figure(figsize=(15, 8))

for cycle in sorted(df['Halving'].unique()):
    cycle_data = df[df['Halving'] == cycle]
    days_from_start = (cycle_data['Timestamp'] - cycle_data['Timestamp'].iloc[0]).dt.total_seconds() / (24*60*60)
    
    # Filter for days between 200 and 400
    mask = (days_from_start >= 200) & (days_from_start <= 400)
    filtered_days = days_from_start[mask]
    
    normalized_prices = cycle_data['Close'] / cycle_data['Close'].iloc[0] * 100
    filtered_prices = normalized_prices[mask]
    
    plt.plot(filtered_days, filtered_prices, label=f'Halving {cycle}', alpha=1.0)
        
    # Plot markers for negative events (red)
    for target_date in negative_events:
        event_mask = (cycle_data['Timestamp'].dt.date == target_date.date()) & mask
        if any(event_mask):
            event_day = filtered_days[event_mask].iloc[0]
            event_price = filtered_prices[event_mask].iloc[0]
            plt.plot(event_day, event_price, 'ro', markersize=5)  # Red dot
        
    # Plot markers for positive events (green)
    for target_date in positive_events:
        event_mask = (cycle_data['Timestamp'].dt.date == target_date.date()) & mask
        if any(event_mask):
            event_day = filtered_days[event_mask].iloc[0]
            event_price = filtered_prices[event_mask].iloc[0]
            plt.plot(event_day, event_price, 'go', markersize=5)  # Green dot

plt.title('Normalized Bitcoin Price Changes by Halving Cycle (Days 200-400)')
plt.xlabel('Days from Start of Cycle')
plt.ylabel('Price (Normalized to 100)')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %% [markdown]
# 4. pattern recognition
# - use halving dates as anchors
# - run statistical models such as ARIMA to identify cyclical trends or fourier transforms to detect recurring seasonal patterns
# - calculate average drawdowns after events like the Mt. Gox collapse or China bans

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# halving dates
halving_dates = [
    pd.to_datetime('2012-11-28 15:24:37'),
    pd.to_datetime('2016-07-09 16:46:13'),
    pd.to_datetime('2020-05-11 19:23:43'),
    pd.to_datetime('2024-04-20 12:09:27')  # Example date for the fourth cycle
]

# Add a column for cycle number
df['Cycle'] = 0
for i, date in enumerate(halving_dates[:-1]):
    df.loc[(df['Timestamp'] >= date) & (df['Timestamp'] < halving_dates[i+1]), 'Cycle'] = i + 1

# Analyze each cycle
for cycle in df['Cycle'].unique():
    cycle_data = df[df['Cycle'] == cycle].copy()
    cycle_data.set_index('Timestamp', inplace=True)
    
    # Fit ARIMA model
    model = ARIMA(cycle_data['Close'], order=(1, 1, 1))  # Example order, adjust as needed
    model_fit = model.fit()
    
    # Print summary
    print(f"Cycle {cycle} ARIMA Model Summary:")
    print(model_fit.summary())
    
    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.plot(cycle_data['Close'], label='Actual')
    plt.plot(model_fit.fittedvalues, color='red', label='Fitted')
    plt.title(f'Cycle {cycle} - ARIMA Model')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Cycle 1 ARIMA Model Summary:

# %%
# aggregate the data from seconds to days

# %%
daily_df

print(len(daily_df))

print(len(df))
# Out:
#       Timestamp       Open       High        Low      Close       Volume
# 0    2012-11-28      12.10      12.27      12.10      12.20  1405.817487
# 1    2012-11-29      12.20      12.41      12.10      12.38  4237.544909
# 2    2012-11-30      12.38      12.44      12.10      12.42  4095.587724
# 3    2012-12-01      12.42      12.46      12.31      12.34  2837.370411
# 4    2012-12-02      12.34      12.45      12.24      12.45  1636.219308
# ...         ...        ...        ...        ...        ...          ...
# 4437 2025-01-21  102155.00  102253.00  102013.00  102174.00     0.163635
# 4438 2025-01-22  105489.00  105541.00  103322.00  103632.00  1498.871094
# 4439 2025-01-23  103659.00  103659.00  103613.00  103613.00     0.011257
# 4440 2025-01-24  104785.00  107149.00  104478.00  104855.00  1384.529311
# 4441 2025-01-25  104855.00  104855.00  104711.00  104711.00     0.603881
#
# [4442 rows x 6 columns]

# %%
# aggregating by days

import pandas as pd

# Assuming df is your original DataFrame with a 'Timestamp' column in datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')  # Ensure Timestamp is in datetime format

# Set the 'Timestamp' as the index
df.set_index('Timestamp', inplace=True)

# Resample the data to daily frequency and aggregate
daily_df = df.resample('D').agg({
    'Open': 'first',   # First value of the day
    'High': 'max',     # Maximum value of the day
    'Low': 'min',      # Minimum value of the day
    'Close': 'last',   # Last value of the day
    'Volume': 'sum',    # Sum of the volume for the day
    'Halving': 'max'
})

# Reset the index if you want 'Timestamp' as a column again
daily_df.reset_index(inplace=True)

# Display the first few rows of the new daily DataFrame
print(daily_df.head())
# Out:
#    Timestamp  Open  High   Low  Close      Volume  Halving
# 0 2012-01-01  4.58  4.84  4.58   4.84   10.000000        0
# 1 2012-01-02  4.84  5.00  4.84   5.00   10.100000        0
# 2 2012-01-03  5.00  5.32  5.00   5.29  107.085281        0
# 3 2012-01-04  5.29  5.57  4.93   5.57  107.233260        0
# 4 2012-01-05  5.57  6.46  5.57   6.42   70.328742        0

# %%
daily_df = daily_df[daily_df['Halving'] != 0]

# Verify the changes
print("DataFrame after removing rows with Halving = 0:")
print(daily_df.head())
# Out:
# DataFrame after removing rows with Halving = 0:
#      Timestamp   Open   High    Low  Close       Volume  Halving
# 332 2012-11-28  11.95  12.74  11.90  12.20  3101.917690        1
# 333 2012-11-29  12.20  12.41  12.10  12.38  4237.544909        1
# 334 2012-11-30  12.38  12.44  12.10  12.42  4095.587724        1
# 335 2012-12-01  12.42  12.46  12.31  12.34  2837.370411        1
# 336 2012-12-02  12.34  12.45  12.24  12.45  1636.219308        1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create single plot
fig, ax1 = plt.subplots(figsize=(15, 8))

# Plot price trends by halving cycle
for cycle in sorted(daily_df['Halving'].unique()):
    cycle_data = daily_df[daily_df['Halving'] == cycle]
    ax1.plot(cycle_data['Timestamp'], cycle_data['Close'], 
             label=f'Halving {cycle}', alpha=0.8)

ax1.set_title('Bitcoin Price During Different Halving Cycles')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price (USD)')
ax1.legend()
# ax1.set_yscale('log')  # Using log scale since price changes are exponential
ax1.grid(True)

plt.tight_layout()
plt.show()

# Alternative visualization: Normalized price changes
plt.figure(figsize=(15, 8))

for cycle in sorted(daily_df['Halving'].unique()):
    cycle_data = daily_df[daily_df['Halving'] == cycle]
    # Normalize prices to start at 100 for each cycle
    normalized_prices = cycle_data['Close'] / cycle_data['Close'].iloc[0] * 100
    # Create relative timeindex (days from start of cycle)
    days_from_start = (cycle_data['Timestamp'] - cycle_data['Timestamp'].iloc[0]).dt.total_seconds() / (24*60*60)
    
    plt.plot(days_from_start, normalized_prices, label=f'Halving {cycle}', alpha=0.8)

plt.title('Normalized Bitcoin Price Changes by Halving Cycle')
plt.xlabel('Days from Start of Cycle')
plt.ylabel('Price (Normalized to 100)')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()
